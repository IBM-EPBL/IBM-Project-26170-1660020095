# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/REALTIME.zip'
# Out:
# Archive:  /content/drive/MyDrive/REALTIME.zip
#    creating: IBMDATASET/Test/
#    creating: IBMDATASET/Test/A/
#   inflating: IBMDATASET/Test/A/Image_1667714449.7824135.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.2819173.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.3281891.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.370591.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.446694.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.731246.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.770862.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.827396.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.9089375.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.9475768.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714450.9875486.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714451.0274093.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714451.0664663.jpg
#   inflating: IBMDATASET/Test/A/Image_1667714451.3494403.jpg
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory('/content/drive/MyDrive/IBMDATASET/Train',target_size=(64,64),batch_size=300,class_mode='categorical',color_mode="grayscale")
# Out:
# Found 1000 images belonging to 10 classes.

# %%
x_train=train_datagen.flow_from_directory('/content/drive/MyDrive/IBMDATASET/Test',target_size=(64,64),batch_size=300,class_mode='categorical',color_mode="grayscale")
# Out:
# Found 514 images belonging to 10 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %%
model = Sequential()

# %%
model.add(Convolution2D(32,(3,3),input_shape=(64,64,1), activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=512, activation = 'relu'))

# %%
model.add(Dense(units=9, activation = 'softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
